# %%
ROSES_TRADES = "..."


COCONUT_TRADES = "..."

COCONUT_COUPON_TRADES = "..."

BASKETS_TRADES = "..."

# %%
len(ROSES_TRADES)
# Out:
# 10000

# %%
len(COCONUT_TRADES)
# Out:
# 10000

# %%
len(COCONUT_COUPON_TRADES)
# Out:
# 10000

# %%
len(BASKETS_TRADES)
# Out:
# 10000
